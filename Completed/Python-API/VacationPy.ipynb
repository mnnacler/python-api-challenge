# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import requests
import json

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
weatherInfo = pd.read_csv("WeatherInfo.csv")
weatherInfo.head()
# Out:
#               City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  port hawkesbury  45.62  -61.35     51.01     100.0        90.0       11.41
# 1           maputo -25.97   32.59     70.00      78.0        16.0        4.00
# 2        busselton -33.65  115.33     55.00      66.0         1.0       10.92
# 3            kapaa  22.08 -159.32     84.99      74.0        90.0        3.36
# 4    alice springs -23.70  133.88     82.40      34.0         2.0        6.93
#
#   Country          Date
# 0      CA  1.603320e+09
# 1      MZ  1.603320e+09
# 2      AU  1.603320e+09
# 3      US  1.603320e+09
# 4      AU  1.603320e+09

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
gmaps.configure(api_key=g_key)
weatherInfoNew = weatherInfo.dropna()
locations = weatherInfoNew[["Lat", "Lng"]].astype(float)
humidity = weatherInfoNew["Humidity"].astype(float)
# Out:
# 0      100.0
# 1       78.0
# 2       66.0
# 3       74.0
# 4       34.0
#        ...
# 607     80.0
# 608     98.0
# 609     84.0
# 610     96.0
# 611     92.0
# Name: Humidity, Length: 552, dtype: float64

# %%
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, weights=humidity, 
                                 dissipating=False, max_intensity=100,
                                 point_radius = 1)

fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
#max temp between 65 and 85, cloudiness <= 25%, humidity <= 60%
hotel_df = weatherInfoNew.loc[(weatherInfoNew["Max Temp"] >= 65) &
                                    (weatherInfoNew["Max Temp"] <= 85) &
                                    (weatherInfoNew["Cloudiness"] <= 25) &
                                    (weatherInfoNew["Humidity"] <= 60), :]
hotel_df = hotel_df.dropna()
hotel_df
# Out:
#               City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 4    alice springs -23.70  133.88     82.40      34.0         2.0        6.93
# 27           houma  29.60  -90.72     82.00      60.0         8.0        8.01
# 31             soe  -9.86  124.28     75.65      58.0         7.0        2.30
# 46           kabwe -14.45   28.45     73.54      42.0         0.0       10.74
# 52          marzuq  14.40   46.47     68.34      25.0        16.0        3.87
# 89   pacific grove  36.62 -121.92     78.01      60.0         1.0        5.82
# 96          tairua -37.02  175.85     66.58      59.0        21.0        4.70
# 125       tessalit  20.20    1.01     84.11      15.0         0.0        8.55
# 126       riverton  40.52 -111.94     73.00      42.0         1.0       10.29
# 138      fruitvale  39.08 -108.50     75.99      11.0         1.0       13.87
# 143        luangwa -15.62   30.42     82.60      45.0         0.0       12.71
# ...

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_df["Hotel Name"] = ""
hotel_df
# Out:
#               City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 4    alice springs -23.70  133.88     82.40      34.0         2.0        6.93
# 27           houma  29.60  -90.72     82.00      60.0         8.0        8.01
# 31             soe  -9.86  124.28     75.65      58.0         7.0        2.30
# 46           kabwe -14.45   28.45     73.54      42.0         0.0       10.74
# 52          marzuq  14.40   46.47     68.34      25.0        16.0        3.87
# 89   pacific grove  36.62 -121.92     78.01      60.0         1.0        5.82
# 96          tairua -37.02  175.85     66.58      59.0        21.0        4.70
# 125       tessalit  20.20    1.01     84.11      15.0         0.0        8.55
# 126       riverton  40.52 -111.94     73.00      42.0         1.0       10.29
# 138      fruitvale  39.08 -108.50     75.99      11.0         1.0       13.87
# 143        luangwa -15.62   30.42     82.60      45.0         0.0       12.71
# ...

# %%
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
target_search = "Hotel"
target_radius = 5000
target_type = "Hotel"

params = {
    "keyword": target_search,
    #"radius": target_radius,
    "rankby": "distance",
    "type": target_type,
    "key": g_key
}


for index, row in hotel_df.iterrows():
    lat = row["Lat"]
    lng = row["Lng"]
    city = row["City"]

    params["location"] = f"{lat},{lng}"
      
    response = requests.get(base_url, params=params).json()
    
    # extract results
    results = response['results']
    
    try:
        print(f"Closest hotel to {city} is {results[0]['name']}.")
        
        hotel_df.loc[index, 'Hotel Name'] = results[0]['name']
        
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
        
    print("------------")
# Out:
# Closest hotel to alice springs is Elkira Court Motel.
# ------------
# Closest hotel to houma is Courtyard by Marriott Houma.
# ------------
# Closest hotel to soe is Dena Hotel.
# ------------
# Closest hotel to kabwe is Pilgrims Motel.
# ------------
# Missing field/result... skipping.
# ------------
# Closest hotel to pacific grove is Pacific Grove Inn.
# ------------
# Closest hotel to tairua is Pauanui Pines Motor Lodge.
# ------------
# Missing field/result... skipping.
# ------------
# Closest hotel to riverton is Homewood Suites by Hilton Salt Lake City Draper.
# ------------
# Closest hotel to fruitvale is Best Western Grande River Inn & Suites.
# ------------
# Closest hotel to luangwa is Feira Lodge (Council Lodge).
# ------------
# Missing field/result... skipping.
# ------------
# Closest hotel to tukrah is مطعم الحيطة.
# ------------
# Missing field/result... skipping.
# ------------
# Closest hotel to susangerd is Hall, Hotel And Restaurant Ghasr.
# ------------
# ...

# %%
hotel_df
# Out:
#               City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 4    alice springs -23.70  133.88     82.40      34.0         2.0        6.93
# 27           houma  29.60  -90.72     82.00      60.0         8.0        8.01
# 31             soe  -9.86  124.28     75.65      58.0         7.0        2.30
# 46           kabwe -14.45   28.45     73.54      42.0         0.0       10.74
# 52          marzuq  14.40   46.47     68.34      25.0        16.0        3.87
# 89   pacific grove  36.62 -121.92     78.01      60.0         1.0        5.82
# 96          tairua -37.02  175.85     66.58      59.0        21.0        4.70
# 125       tessalit  20.20    1.01     84.11      15.0         0.0        8.55
# 126       riverton  40.52 -111.94     73.00      42.0         1.0       10.29
# 138      fruitvale  39.08 -108.50     75.99      11.0         1.0       13.87
# 143        luangwa -15.62   30.42     82.60      45.0         0.0       12.71
# ...

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map
markers = gmaps.marker_layer(locations)
fig.add_layer(markers)
# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
